# %%
import sys

print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")
print(f"Working directory: {sys.path[0]}")

# Test our core ML imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

print("✅ All ML imports successful!")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")
# Out:
# Python version: 3.13.7 (main, Aug 14 2025, 11:12:11) [Clang 17.0.0 (clang-1700.0.13.3)]
# Python executable: /Users/armelhell/Documents/MLTeachings/ml-playground/ml-env/bin/python
# Working directory: /opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python313.zip
# ✅ All ML imports successful!
# NumPy version: 2.3.3
# Pandas version: 2.3.2

# %%
# This is the magic - importing from our own package!
from src.utils import hello_ml

# Test our function
result = hello_ml()
print(f"Function returned: {result}")
# Out:
# Hello from ML Playground package! Tying these stuffs for the first time.
# Function returned: Package working correctly!

# %%
# Create some sample data
X, y = make_classification(n_samples=100, n_features=2, n_redundant=0, random_state=42)

# Create a DataFrame (testing pandas)
df = pd.DataFrame(X, columns=["feature_1", "feature_2"])
df["target"] = y

print("Sample data shape:", df.shape)
print("\nFirst 5 rows:")
print(df.head())

# Quick visualization (testing matplotlib)
plt.figure(figsize=(8, 6))
scatter = plt.scatter(df["feature_1"], df["feature_2"], c=df["target"], cmap="viridis")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Sample ML Dataset")
plt.colorbar(scatter)
plt.show()

print("✅ Visualization complete!")
# Out:
# Sample data shape: (100, 3)
#
# First 5 rows:
#    feature_1  feature_2  target
# 0   0.559426   2.388694       0
# 1   1.312175  -0.717315       1
# 2  -1.559849  -1.924874       0
# 3  -2.281386  -0.136856       0
# 4   1.560704  -0.427958       1
# ✅ Visualization complete!

# %%
# Let's modify our utils.py file and see if changes are immediate
# First, let's see what our current function does
from src.utils import hello_ml

hello_ml()
# Out:
# Hello from ML Playground package! Tying these stuffs for the first time.
# 'Package working correctly, hiyeee!'

# %%
# Cell 1 - Run this once at the start
# %load_ext autoreload
# %autoreload 2

# Test the new function immediately (no restart needed!)
from src.utils import create_sample_data

# This should work immediately thanks to editable installation
sample_df = create_sample_data(n_samples=50, n_features=3)
print(sample_df.head())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ✅ Created dataset with 50 samples and 3 features
#    feature_1  feature_2  feature_3  target
# 0  -0.793821  -0.783316  -0.192361       0
# 1   1.215244   1.100919   0.787085       1
# 2   0.330949   0.853495  -0.714351       1
# 3   0.808465  -0.339412  -1.062304       1
# 4   0.640276   0.886033  -0.974682       1
